# %% [markdown]
# # EDA Notebook
#
# This notebook contains all the data plots that are used within the simulation.

# %% [markdown]
# # Imports

# %%
import pandas as pd

# %% [markdown]
# # DATA

# %%
batch_run_df = pd.read_csv("simulation_output/aggregate_sim_data.csv")
batch_run_df.head()
# Out:
#              simulation_name  run_number  prosumers  perfect_forecasting  \
# 0  prosumer5_bilateral_kNone           1          5                False
# 1  prosumer5_bilateral_kNone           2          5                False
# 2  prosumer5_bilateral_kNone           3          5                False
# 3  prosumer5_bilateral_kNone           4          5                False
# 4  prosumer5_bilateral_kNone           5          5                False
#
#   exchange_type  amm_liquidity_k  Total Overproduction  Total Shortfall  \
# 0     bilateral              NaN              85.12359       412.098043
# 1     bilateral              NaN              85.12359       412.098043
# 2     bilateral              NaN              85.12359       412.098043
# 3     bilateral              NaN              85.12359       412.098043
# 4     bilateral              NaN              85.12359       412.098043
#
#    Total Bought  Total Bought Expenditure  ...  Total Production for Demand  \
# 0    635.213375                199.675577  ...                  1347.845176
# 1    635.213375                199.675577  ...                  1347.845176
# 2    635.213375                199.675577  ...                  1347.845176
# 3    635.213375                199.675577  ...                  1347.845176
# 4    635.213375                199.675577  ...                  1347.845176
#
#    Total Production for Market  Total Production for Utility  \
# 0                   317.557598                      85.12359
# 1                   317.557598                      85.12359
# 2                   317.557598                      85.12359
# 3                   317.557598                      85.12359
# 4                   317.557598                      85.12359
#
#    Running Energy Sold  Running Actual Production  Seller Average Price  \
# 0           635.213375                1750.526363              0.156359
# 1           635.213375                1750.526363              0.156359
# 2           635.213375                1750.526363              0.156359
# 3           635.213375                1750.526363              0.156359
# 4           635.213375                1750.526363              0.156359
#
#    Proportion of Total Production Sold into Market  \
# 0                                         0.181407
# 1                                         0.181407
# 2                                         0.181407
# 3                                         0.181407
# 4                                         0.181407
#
#    Proportion of Excess Sold into Market  Total System Demand  \
# 0                               0.788608         20436.903643
# 1                               0.788608         20436.903643
# 2                               0.788608         20436.903643
# 3                               0.788608         20436.903643
# 4                               0.788608         20436.903643
#
#    Total System Production
# 0              1750.526363
# 1              1750.526363
# 2              1750.526363
# 3              1750.526363
# 4              1750.526363
#
# [5 rows x 26 columns]

# %%
batch_run_df.shape
# Out:
# (30, 26)
